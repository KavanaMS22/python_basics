# %%
num1=10
num2=20
num1+num2
# Out:
# 30

# %%
num1*num2
# Out:
# 200

# %%
num1%num2
# Out:
# 10

# %%
num1 +=5

# %%
num1

# %%
num1 +=5
num1

# %%
num1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d05396c398c6> in <cell line: 1>()
# ----> 1 num1
#
# NameError: name 'num1' is not defined

# %%
num1 +=5
num1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b9954dcc87e> in <cell line: 1>()
# ----> 1 num1 +=5
#       2 num1
#
# NameError: name 'num1' is not defined

# %%
num1=10
num1 +=5
num1
# Out:
# 15

# %%
num1=10
num2=20
num1==num2
# Out:
# False

# %%
num1>num2
# Out:
# False

# %%
num1<num2
# Out:
# True

# %%
num1>=num2
# Out:
# False

# %%
num1<=num2
# Out:
# True

# %%
num1!=num2
# Out:
# True

# %%
a=10
b=20
a and b
# Out:
# 20

# %%
10100 and 10100
# Out:
# 10100

# %%
customer_name="lina"
customer_id= 2229
type(customer_id)
#type(customer_name)
# Out:
# int

# %%
type(customer_name)
# Out:
# str

# %%
print("customer name is", customer_name, "and customer id is",customer_id)
# Out:
# customer name is lina and customer id is 2229

# %%
b="1000"
int(str(b))
# Out:
# 1000

# %%
a=29
str(int(a))
# Out:
# '29'

# %%
name= input("enter your name....")
# Out:
# enter your name....kavana

# %%
num1 =int(input("enter first number"))
num2 = int(input("enter second number"))
sum=num1+num2
print(sum)
# Out:
# enter first number22
# enter second number29
# 51

# %%
num =int(input("enter a number"))
if num ==7 :
  print("welcome")
else:
 print("enter crt pswd")
# Out:
# enter a number8
# enter crt pswd

# %%
marks =float(input("enter your marks:"))
if marks >= 90:
  print("your performance is outstanding")
elif marks >=75:
  print("grade A")
elif marks >=60:
  print("grade b")
elif marks>=40:
  print("grade c")
else :
  print("need improvement")
# Out:
# enter your marks:98.3
# your performance is outstanding

# %%
num = int(input("enter a number"))
if num>0:
  if num%2 ==0:
    print("number is positive and even")
  else:
    print("number is positive and odd")
elif num==0:
  print("number is zero")
else:
  print("number is negative")
# Out:
#   File "<ipython-input-29-2e949e395bd1>", line 11
#     except ValueError:
#     ^
# SyntaxError: invalid syntax
